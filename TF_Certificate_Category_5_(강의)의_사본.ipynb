# %% [markdown]
# <a href="https://colab.research.google.com/github/Henrykim1111/tensorflow-developer-certificate/blob/main/TF_Certificate_Category_5_(%EA%B0%95%EC%9D%98)%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Category 5
#
# Sequence (시계열) 데이터 다루기

# %% [markdown]
# ## 확인

# %% [markdown]
# 1. GPU 옵션 켜져 있는지 확인할 것!!! (수정 - 노트설정 - 하드웨어설정 (GPU))

# %% [markdown]
# ## 순서

# %% [markdown]
# 1. **import**: 필요한 모듈 import
# 2. **전처리**: 학습에 필요한 데이터 전처리를 수행합니다.
# 3. **모델링(model)**: 모델을 정의합니다.
# 4. **컴파일(compile)**: 모델을 생성합니다.
# 5. **학습 (fit)**: 모델을 학습시킵니다.

# %% [markdown]
# ## 문제

# %% [markdown]
# For this task you will need to train a neural network
# to predict sunspot activity using the Sunspots.csv
# provided.
#
# Your neural network is expected to have an MAE
# of at least 20, with top marks going to one with an MAE
# of around 15.
#
# At the bottom is provided some testing
# code should you want to check before uploading which measures
# the MAE for you.
#
# Strongly recommend you test your model with
# this to be able to see how it performs.
#
#
#
# -------------------------------
# **Sequence(시퀀스)**
#
# Sunspots.csv를 사용하여 **태양 흑점 활동(sunspot)**을 예측하는 인공신경망을 만듭니다.
#
# MAE 오차 기준으로 최소 20이하로 예측할 것을 권장하며, 탑 랭킹에 들려면 MAE 15 근처에 도달해야합니다.
#
# 아래 주어진 샘플코드는 당신의 모델을 테스트 하는 용도로 활용할 수 있습니다.

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ## 필요한 모듈 import

# %%
import csv
import tensorflow as tf
import numpy as np
import urllib

from tensorflow.keras.layers import Dense, LSTM, Lambda, Conv1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import Huber

# %%
url = 'https://storage.googleapis.com/download.tensorflow.org/data/Sunspots.csv'
urllib.request.urlretrieve(url, 'sunspots.csv')
# Out:
# ('sunspots.csv', <http.client.HTTPMessage at 0x7d56e577cf70>)

# %% [markdown]
# ## csv 파일로부터 데이터셋 만들기

# %% [markdown]
# csv.reader() 함수를 활용합니다.
#
# * 첫번째 파라미터에는 file을 , delimiter에는 구분자를 넣어 줍니다.

# %%
with open('sunspots.csv') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    i = 0
    for row in reader:
        print(row)
        i+=1
        if i > 10:
            break
# Out:
# ['0', '1749-01-31', '96.7']
# ['1', '1749-02-28', '104.3']
# ['2', '1749-03-31', '116.7']
# ['3', '1749-04-30', '92.8']
# ['4', '1749-05-31', '141.7']
# ['5', '1749-06-30', '139.2']
# ['6', '1749-07-31', '158.0']
# ['7', '1749-08-31', '110.5']
# ['8', '1749-09-30', '126.5']
# ['9', '1749-10-31', '125.8']
# ['10', '1749-11-30', '264.3']

# %% [markdown]
# 빈 list를 만들어 줍니다. (sunspots, time_step)

# %%
sunspots = []
time_step = []

# %% [markdown]
# `time_step`에는 **index** 값을, `sunspots`에는 sunspots의 정보를 넣어 줍니다.

# %%
with open('sunspots.csv') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    # 첫 줄은 header이므로 skip 합니다.
    next(reader)
    for row in reader:
        sunspots.append(float(row[2]))
        time_step.append(int(row[0]))

# %% [markdown]
# sunspots, time_step 확인

# %%
sunspots[:5]
# Out:
# [96.7, 104.3, 116.7, 92.8, 141.7]

# %%
time_step[:5]
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# sunspots와 time_step을 `numpy array`로 변환합니다.
#
# * 참고: 모델은 list 타입을 받아들이지 못합니다. 따라서, numpy array 로 변환해 줍니다.

# %%
series = np.array(sunspots)
time = np.array(time_step)

# %%
series.shape, time.shape
# Out:
# ((3235,), (3235,))

# %% [markdown]
# ## 태양의 흑점 활동 (sunspots) 시각화

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 8))
plt.plot(time, series)
plt.xlabel("Time")
plt.ylabel("Value")
plt.grid(True)

# %% [markdown]
# ## Train Set, Validation Set 생성

# %% [markdown]
# 3000 인덱스를 기준으로 Train / Validation Set를 분할 합니다.

# %%
split_time = 3000

# %%
time_train = time[:split_time]
time_valid = time[split_time:]

x_train = series[:split_time]
x_valid = series[split_time:]

# %% [markdown]
# ## Window Dataset Loader

# %% [markdown]
# 자세한 Dataset 활용법은 [블로그 링크](https://teddylee777.github.io/tensorflow/dataset-batch-window)를 참고해 보시고, 연습해보세요!

# %%
# 윈도우 사이즈
window_size=30
# 배치 사이즈
batch_size = 32
# 셔플 사이즈
shuffle_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)

# %% [markdown]
# `train_set`와 `validation_set`를 만듭니다.

# %%
train_set = windowed_dataset(x_train,
                             window_size=window_size,
                             batch_size=batch_size,
                             shuffle_buffer=shuffle_size)

validation_set = windowed_dataset(x_valid,
                                  window_size=window_size,
                                  batch_size=batch_size,
                                  shuffle_buffer=shuffle_size)

# %% [markdown]
# ## 모델 정의 (Sequential)

# %%
from IPython.display import Image

Image('https://i.stack.imgur.com/NmYZJ.png')

# %%
model = Sequential([
    tf.keras.layers.Conv1D(60, kernel_size=5,
                         padding="causal",
                         activation="relu",
                         input_shape=[None, 1]),
    tf.keras.layers.LSTM(60, return_sequences=True),
    tf.keras.layers.LSTM(60, return_sequences=True),
    tf.keras.layers.Dense(30, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 400)
])

# %% [markdown]
# 모델의 구조 요약을 확인합니다.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 60)          360
#
#  lstm (LSTM)                 (None, None, 60)          29040
#
#  lstm_1 (LSTM)               (None, None, 60)          29040
#
#  dense (Dense)               (None, None, 30)          1830
#
#  dense_1 (Dense)             (None, None, 10)          310
#
#  dense_2 (Dense)             (None, None, 1)           11
#
#  lambda (Lambda)             (None, None, 1)           0
#
# =================================================================
# Total params: 60591 (236.68 KB)
# Trainable params: 60591 (236.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 컴파일 (compile)

# %% [markdown]
# **Optimizer**는 SGD(Stochastic Gradient Descent) 를 사용합니다.
#
# * lr(learning_rate): 학습률입니다.
# * momentum: 모멘텀 (가중치) 입니다.

# %%
optimizer = SGD(learning_rate=1e-5, momentum=0.9)

# %% [markdown]
# **Huber Loss**: MSE와 MAE를 절충한 후버 손실(Huber loss)

# %% [markdown]
# \begin{split}L_{\delta}=\left\{\begin{matrix}
# \frac{1}{2}(y - \hat{y})^{2} & if \left | (y - \hat{y})  \right | < \delta\\
# \delta ((y - \hat{y}) - \frac1 2 \delta) & otherwise
# \end{matrix}\right.\end{split}

# %%
loss= Huber()

# %% [markdown]
# model.compile()시 우리가 튜닝한 **optimizer**와 **loss**를 활용합니다.

# %%
model.compile(loss=loss,
              optimizer=optimizer,
              metrics=["mae"])

# %% [markdown]
# ## ModelCheckpoint: 체크포인트 생성

# %% [markdown]
# `val_loss` 기준으로 epoch 마다 최적의 모델을 저장하기 위하여, ModelCheckpoint를 만듭니다.
# * `checkpoint_path`는 모델이 저장될 파일 명을 설정합니다.
# * `ModelCheckpoint`을 선언하고, 적절한 옵션 값을 지정합니다.

# %%
checkpoint_path = 'tmp_checkpoint.ckpt'
checkpoint = ModelCheckpoint(checkpoint_path,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_mae',
                             verbose=1)

# %% [markdown]
# ## 학습 (fit)

# %%
epochs=100

# %%
history = model.fit(train_set,
                    validation_data=(validation_set),
                    epochs=epochs,
                    callbacks=[checkpoint],
                   )
# Out:
# Epoch 1/100
#      92/Unknown - 5s 12ms/step - loss: 92.8104 - mae: 93.3090
# Epoch 1: val_mae improved from inf to 46.99323, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 5s 22ms/step - loss: 92.4686 - mae: 92.9672 - val_loss: 46.4934 - val_mae: 46.9932
# Epoch 2/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.8615 - mae: 54.3597
# Epoch 2: val_mae improved from 46.99323 to 46.53285, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 14ms/step - loss: 54.0888 - mae: 54.5871 - val_loss: 46.0367 - val_mae: 46.5329
# Epoch 3/100
# 93/93 [==============================] - ETA: 0s - loss: 54.0238 - mae: 54.5220
# Epoch 3: val_mae improved from 46.53285 to 46.37324, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0238 - mae: 54.5220 - val_loss: 45.8748 - val_mae: 46.3732
# Epoch 4/100
# 93/93 [==============================] - ETA: 0s - loss: 54.0339 - mae: 54.5321
# Epoch 4: val_mae did not improve from 46.37324
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0339 - mae: 54.5321 - val_loss: 46.3720 - val_mae: 46.8698
# Epoch 5/100
# 89/93 [===========================>..] - ETA: 0s - loss: 53.7637 - mae: 54.2620
# Epoch 5: val_mae did not improve from 46.37324
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0565 - mae: 54.5547 - val_loss: 46.3743 - val_mae: 46.8722
# Epoch 6/100
# 89/93 [===========================>..] - ETA: 0s - loss: 54.1830 - mae: 54.6813
# Epoch 6: val_mae improved from 46.37324 to 46.36696, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0687 - mae: 54.5669 - val_loss: 45.8683 - val_mae: 46.3670
# Epoch 7/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.9826 - mae: 54.4809
# Epoch 7: val_mae improved from 46.36696 to 45.87803, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0908 - mae: 54.5892 - val_loss: 45.3799 - val_mae: 45.8780
# Epoch 8/100
# 91/93 [============================>.] - ETA: 0s - loss: 54.0004 - mae: 54.4985
# Epoch 8: val_mae did not improve from 45.87803
# 93/93 [==============================] - 2s 19ms/step - loss: 54.0461 - mae: 54.5442 - val_loss: 46.4599 - val_mae: 46.9596
# Epoch 9/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.9035 - mae: 54.4019
# Epoch 9: val_mae did not improve from 45.87803
# 93/93 [==============================] - 2s 14ms/step - loss: 53.9862 - mae: 54.4845 - val_loss: 45.3845 - val_mae: 45.8823
# Epoch 10/100
# 89/93 [===========================>..] - ETA: 0s - loss: 53.9101 - mae: 54.4083
# Epoch 10: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 13ms/step - loss: 53.9954 - mae: 54.4936 - val_loss: 47.2346 - val_mae: 47.7346
# Epoch 11/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.8646 - mae: 54.3627
# Epoch 11: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0483 - mae: 54.5464 - val_loss: 45.8198 - val_mae: 46.3193
# Epoch 12/100
# 92/93 [============================>.] - ETA: 0s - loss: 53.9610 - mae: 54.4590
# Epoch 12: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 12ms/step - loss: 53.9585 - mae: 54.4565 - val_loss: 46.0090 - val_mae: 46.5045
# Epoch 13/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.0256 - mae: 54.5238
# Epoch 13: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0937 - mae: 54.5919 - val_loss: 46.2593 - val_mae: 46.7548
# Epoch 14/100
# 88/93 [===========================>..] - ETA: 0s - loss: 54.0113 - mae: 54.5094
# Epoch 14: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 12ms/step - loss: 53.9975 - mae: 54.4956 - val_loss: 46.3742 - val_mae: 46.8720
# Epoch 15/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.0482 - mae: 54.5464
# Epoch 15: val_mae did not improve from 45.87803
# 93/93 [==============================] - 2s 18ms/step - loss: 53.9910 - mae: 54.4892 - val_loss: 45.5761 - val_mae: 46.0760
# Epoch 16/100
# 92/93 [============================>.] - ETA: 0s - loss: 53.9790 - mae: 54.4773
# Epoch 16: val_mae did not improve from 45.87803
# 93/93 [==============================] - 2s 20ms/step - loss: 54.0258 - mae: 54.5241 - val_loss: 45.9269 - val_mae: 46.4231
# Epoch 17/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.9291 - mae: 54.4273
# Epoch 17: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1155 - mae: 54.6137 - val_loss: 45.4717 - val_mae: 45.9704
# Epoch 18/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.9144 - mae: 54.4127
# Epoch 18: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0438 - mae: 54.5420 - val_loss: 46.3280 - val_mae: 46.8238
# Epoch 19/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.1022 - mae: 54.6007
# Epoch 19: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1576 - mae: 54.6561 - val_loss: 45.4698 - val_mae: 45.9685
# Epoch 20/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.7935 - mae: 54.2917
# Epoch 20: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 14ms/step - loss: 54.0262 - mae: 54.5243 - val_loss: 46.4342 - val_mae: 46.9336
# Epoch 21/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.8795 - mae: 54.3778
# Epoch 21: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0215 - mae: 54.5198 - val_loss: 46.3255 - val_mae: 46.8212
# Epoch 22/100
# 93/93 [==============================] - ETA: 0s - loss: 54.0106 - mae: 54.5089
# Epoch 22: val_mae did not improve from 45.87803
# 93/93 [==============================] - 2s 19ms/step - loss: 54.0106 - mae: 54.5089 - val_loss: 45.7015 - val_mae: 46.1991
# Epoch 23/100
# 93/93 [==============================] - ETA: 0s - loss: 54.2993 - mae: 54.7975
# Epoch 23: val_mae did not improve from 45.87803
# 93/93 [==============================] - 2s 16ms/step - loss: 54.2993 - mae: 54.7975 - val_loss: 45.7316 - val_mae: 46.2288
# Epoch 24/100
# 93/93 [==============================] - ETA: 0s - loss: 54.0108 - mae: 54.5089
# Epoch 24: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0108 - mae: 54.5089 - val_loss: 45.9410 - val_mae: 46.4370
# Epoch 25/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.0170 - mae: 54.5150
# Epoch 25: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 12ms/step - loss: 53.9867 - mae: 54.4847 - val_loss: 46.1578 - val_mae: 46.6538
# Epoch 26/100
# 91/93 [============================>.] - ETA: 0s - loss: 53.8587 - mae: 54.3571
# Epoch 26: val_mae did not improve from 45.87803
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1057 - mae: 54.6042 - val_loss: 47.1382 - val_mae: 47.6382
# Epoch 27/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.8700 - mae: 54.3685
# Epoch 27: val_mae improved from 45.87803 to 45.53495, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0909 - mae: 54.5894 - val_loss: 45.0374 - val_mae: 45.5350
# Epoch 28/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.9747 - mae: 54.4729
# Epoch 28: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0470 - mae: 54.5452 - val_loss: 45.3282 - val_mae: 45.8281
# Epoch 29/100
# 92/93 [============================>.] - ETA: 0s - loss: 53.9203 - mae: 54.4185
# Epoch 29: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.9813 - mae: 54.4796 - val_loss: 45.8022 - val_mae: 46.3016
# Epoch 30/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.0498 - mae: 54.5480
# Epoch 30: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 20ms/step - loss: 54.0711 - mae: 54.5693 - val_loss: 45.6137 - val_mae: 46.1129
# Epoch 31/100
# 89/93 [===========================>..] - ETA: 0s - loss: 53.9935 - mae: 54.4919
# Epoch 31: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 19ms/step - loss: 54.0944 - mae: 54.5928 - val_loss: 45.1110 - val_mae: 45.6057
# Epoch 32/100
# 91/93 [============================>.] - ETA: 0s - loss: 53.9112 - mae: 54.4094
# Epoch 32: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.9213 - mae: 54.4194 - val_loss: 46.0239 - val_mae: 46.5199
# Epoch 33/100
# 93/93 [==============================] - ETA: 0s - loss: 53.9482 - mae: 54.4465
# Epoch 33: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.9482 - mae: 54.4465 - val_loss: 45.8159 - val_mae: 46.3154
# Epoch 34/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.1018 - mae: 54.6001
# Epoch 34: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1938 - mae: 54.6921 - val_loss: 45.4961 - val_mae: 45.9957
# Epoch 35/100
# 92/93 [============================>.] - ETA: 0s - loss: 53.9202 - mae: 54.4183
# Epoch 35: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.9916 - mae: 54.4897 - val_loss: 45.7760 - val_mae: 46.2749
# Epoch 36/100
# 91/93 [============================>.] - ETA: 0s - loss: 54.0425 - mae: 54.5406
# Epoch 36: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0317 - mae: 54.5299 - val_loss: 45.7917 - val_mae: 46.2910
# Epoch 37/100
# 91/93 [============================>.] - ETA: 0s - loss: 53.9053 - mae: 54.4034
# Epoch 37: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1082 - mae: 54.6063 - val_loss: 45.7289 - val_mae: 46.2262
# Epoch 38/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.8087 - mae: 54.3067
# Epoch 38: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 19ms/step - loss: 54.0796 - mae: 54.5776 - val_loss: 45.5957 - val_mae: 46.0953
# Epoch 39/100
# 91/93 [============================>.] - ETA: 0s - loss: 53.8170 - mae: 54.3152
# Epoch 39: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0267 - mae: 54.5250 - val_loss: 45.5933 - val_mae: 46.0930
# Epoch 40/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.6879 - mae: 54.1859
# Epoch 40: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 12ms/step - loss: 53.9934 - mae: 54.4914 - val_loss: 45.3535 - val_mae: 45.8529
# Epoch 41/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.8764 - mae: 54.3747
# Epoch 41: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0291 - mae: 54.5273 - val_loss: 45.1052 - val_mae: 45.6003
# Epoch 42/100
# 93/93 [==============================] - ETA: 0s - loss: 54.0617 - mae: 54.5599
# Epoch 42: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 14ms/step - loss: 54.0617 - mae: 54.5599 - val_loss: 45.1690 - val_mae: 45.6673
# Epoch 43/100
# 91/93 [============================>.] - ETA: 0s - loss: 53.6854 - mae: 54.1835
# Epoch 43: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.8672 - mae: 54.3653 - val_loss: 46.7530 - val_mae: 47.2472
# Epoch 44/100
# 91/93 [============================>.] - ETA: 0s - loss: 54.0159 - mae: 54.5143
# Epoch 44: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 17ms/step - loss: 54.1153 - mae: 54.6136 - val_loss: 45.7387 - val_mae: 46.2362
# Epoch 45/100
# 89/93 [===========================>..] - ETA: 0s - loss: 53.8565 - mae: 54.3547
# Epoch 45: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 12ms/step - loss: 54.0636 - mae: 54.5618 - val_loss: 45.9439 - val_mae: 46.4397
# Epoch 46/100
# 91/93 [============================>.] - ETA: 0s - loss: 54.0561 - mae: 54.5544
# Epoch 46: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 14ms/step - loss: 54.0163 - mae: 54.5145 - val_loss: 46.3205 - val_mae: 46.8160
# Epoch 47/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.9046 - mae: 54.4028
# Epoch 47: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0733 - mae: 54.5715 - val_loss: 45.4137 - val_mae: 45.9105
# Epoch 48/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.3432 - mae: 54.8414
# Epoch 48: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.2775 - mae: 54.7757 - val_loss: 45.1259 - val_mae: 45.6193
# Epoch 49/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.8693 - mae: 54.3677
# Epoch 49: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0440 - mae: 54.5423 - val_loss: 45.5362 - val_mae: 46.0362
# Epoch 50/100
# 93/93 [==============================] - ETA: 0s - loss: 54.0332 - mae: 54.5315
# Epoch 50: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 17ms/step - loss: 54.0332 - mae: 54.5315 - val_loss: 46.3079 - val_mae: 46.8034
# Epoch 51/100
# 90/93 [============================>.] - ETA: 0s - loss: 54.1250 - mae: 54.6234
# Epoch 51: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 17ms/step - loss: 54.0382 - mae: 54.5365 - val_loss: 45.9834 - val_mae: 46.4785
# Epoch 52/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.2101 - mae: 54.7085
# Epoch 52: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.2249 - mae: 54.7232 - val_loss: 45.5868 - val_mae: 46.0865
# Epoch 53/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.8465 - mae: 54.3448
# Epoch 53: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.9974 - mae: 54.4957 - val_loss: 45.6317 - val_mae: 46.1304
# Epoch 54/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.6826 - mae: 54.1807
# Epoch 54: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0055 - mae: 54.5036 - val_loss: 45.4302 - val_mae: 45.9270
# Epoch 55/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.7362 - mae: 54.2343
# Epoch 55: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0822 - mae: 54.5803 - val_loss: 46.2656 - val_mae: 46.7610
# Epoch 56/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.7744 - mae: 54.2727
# Epoch 56: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 17ms/step - loss: 54.1671 - mae: 54.6654 - val_loss: 46.3581 - val_mae: 46.8554
# Epoch 57/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.9240 - mae: 54.4221
# Epoch 57: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.9949 - mae: 54.4931 - val_loss: 45.7588 - val_mae: 46.2572
# Epoch 58/100
# 91/93 [============================>.] - ETA: 0s - loss: 53.9887 - mae: 54.4867
# Epoch 58: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0051 - mae: 54.5032 - val_loss: 45.4250 - val_mae: 45.9218
# Epoch 59/100
# 90/93 [============================>.] - ETA: 0s - loss: 54.0240 - mae: 54.5221
# Epoch 59: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1441 - mae: 54.6422 - val_loss: 46.3916 - val_mae: 46.8900
# Epoch 60/100
# 91/93 [============================>.] - ETA: 0s - loss: 54.0276 - mae: 54.5257
# Epoch 60: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0839 - mae: 54.5820 - val_loss: 45.3430 - val_mae: 45.8426
# Epoch 61/100
# 92/93 [============================>.] - ETA: 0s - loss: 53.9319 - mae: 54.4302
# Epoch 61: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 19ms/step - loss: 54.0033 - mae: 54.5016 - val_loss: 45.5494 - val_mae: 46.0494
# Epoch 62/100
# 92/93 [============================>.] - ETA: 0s - loss: 53.9905 - mae: 54.4887
# Epoch 62: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 15ms/step - loss: 53.9641 - mae: 54.4623 - val_loss: 46.6227 - val_mae: 47.1183
# Epoch 63/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.7653 - mae: 54.2634
# Epoch 63: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 12ms/step - loss: 54.0186 - mae: 54.5167 - val_loss: 45.4949 - val_mae: 45.9944
# Epoch 64/100
# 93/93 [==============================] - ETA: 0s - loss: 53.9300 - mae: 54.4284
# Epoch 64: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.9300 - mae: 54.4284 - val_loss: 46.0467 - val_mae: 46.5429
# Epoch 65/100
# 89/93 [===========================>..] - ETA: 0s - loss: 54.0237 - mae: 54.5220
# Epoch 65: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0521 - mae: 54.5503 - val_loss: 45.8819 - val_mae: 46.3800
# Epoch 66/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.5004 - mae: 53.9990
# Epoch 66: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0903 - mae: 54.5889 - val_loss: 45.1280 - val_mae: 45.6216
# Epoch 67/100
# 92/93 [============================>.] - ETA: 0s - loss: 53.7678 - mae: 54.2658
# Epoch 67: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 15ms/step - loss: 53.8422 - mae: 54.3402 - val_loss: 46.9747 - val_mae: 47.4747
# Epoch 68/100
# 93/93 [==============================] - ETA: 0s - loss: 54.1766 - mae: 54.6748
# Epoch 68: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 14ms/step - loss: 54.1766 - mae: 54.6748 - val_loss: 45.2688 - val_mae: 45.7688
# Epoch 69/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.9692 - mae: 54.4673
# Epoch 69: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 21ms/step - loss: 53.9833 - mae: 54.4814 - val_loss: 45.5124 - val_mae: 46.0122
# Epoch 70/100
# 92/93 [============================>.] - ETA: 0s - loss: 53.9255 - mae: 54.4238
# Epoch 70: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 14ms/step - loss: 54.0184 - mae: 54.5167 - val_loss: 45.7414 - val_mae: 46.2390
# Epoch 71/100
# 89/93 [===========================>..] - ETA: 0s - loss: 53.5972 - mae: 54.0955
# Epoch 71: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.8945 - mae: 54.3928 - val_loss: 46.1846 - val_mae: 46.6806
# Epoch 72/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.0283 - mae: 54.5264
# Epoch 72: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0983 - mae: 54.5964 - val_loss: 45.4678 - val_mae: 45.9663
# Epoch 73/100
# 89/93 [===========================>..] - ETA: 0s - loss: 53.8789 - mae: 54.3772
# Epoch 73: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0030 - mae: 54.5014 - val_loss: 45.8728 - val_mae: 46.3713
# Epoch 74/100
# 91/93 [============================>.] - ETA: 0s - loss: 54.1560 - mae: 54.6543
# Epoch 74: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1097 - mae: 54.6080 - val_loss: 45.0933 - val_mae: 45.5888
# Epoch 75/100
# 93/93 [==============================] - ETA: 0s - loss: 53.9356 - mae: 54.4340
# Epoch 75: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 15ms/step - loss: 53.9356 - mae: 54.4340 - val_loss: 45.6395 - val_mae: 46.1379
# Epoch 76/100
# 91/93 [============================>.] - ETA: 0s - loss: 53.8914 - mae: 54.3897
# Epoch 76: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 22ms/step - loss: 53.9661 - mae: 54.4644 - val_loss: 45.8592 - val_mae: 46.3582
# Epoch 77/100
# 89/93 [===========================>..] - ETA: 0s - loss: 53.9830 - mae: 54.4811
# Epoch 77: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 15ms/step - loss: 54.0194 - mae: 54.5175 - val_loss: 45.0977 - val_mae: 45.5932
# Epoch 78/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.8965 - mae: 54.3949
# Epoch 78: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 14ms/step - loss: 53.9926 - mae: 54.4911 - val_loss: 46.6329 - val_mae: 47.1279
# Epoch 79/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.1708 - mae: 54.6690
# Epoch 79: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1155 - mae: 54.6138 - val_loss: 45.3279 - val_mae: 45.8278
# Epoch 80/100
# 92/93 [============================>.] - ETA: 0s - loss: 53.8853 - mae: 54.3837
# Epoch 80: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.9348 - mae: 54.4331 - val_loss: 46.1606 - val_mae: 46.6566
# Epoch 81/100
# 91/93 [============================>.] - ETA: 0s - loss: 53.7987 - mae: 54.2971
# Epoch 81: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 14ms/step - loss: 54.0482 - mae: 54.5466 - val_loss: 45.7112 - val_mae: 46.2087
# Epoch 82/100
# 91/93 [============================>.] - ETA: 0s - loss: 53.9926 - mae: 54.4908
# Epoch 82: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1719 - mae: 54.6702 - val_loss: 45.2554 - val_mae: 45.7554
# Epoch 83/100
# 91/93 [============================>.] - ETA: 0s - loss: 53.7953 - mae: 54.2934
# Epoch 83: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 15ms/step - loss: 53.8823 - mae: 54.3804 - val_loss: 45.7425 - val_mae: 46.2401
# Epoch 84/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.6456 - mae: 54.1439
# Epoch 84: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 20ms/step - loss: 53.9877 - mae: 54.4861 - val_loss: 45.2608 - val_mae: 45.7608
# Epoch 85/100
# 93/93 [==============================] - ETA: 0s - loss: 54.0469 - mae: 54.5451
# Epoch 85: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0469 - mae: 54.5451 - val_loss: 46.5951 - val_mae: 47.0922
# Epoch 86/100
# 93/93 [==============================] - ETA: 0s - loss: 54.0489 - mae: 54.5470
# Epoch 86: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0489 - mae: 54.5470 - val_loss: 45.5970 - val_mae: 46.0966
# Epoch 87/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.8784 - mae: 54.3767
# Epoch 87: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 12ms/step - loss: 54.0032 - mae: 54.5014 - val_loss: 45.7851 - val_mae: 46.2842
# Epoch 88/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.6506 - mae: 54.1485
# Epoch 88: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 53.9511 - mae: 54.4490 - val_loss: 46.3868 - val_mae: 46.8851
# Epoch 89/100
# 88/93 [===========================>..] - ETA: 0s - loss: 53.6676 - mae: 54.1659
# Epoch 89: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0854 - mae: 54.5838 - val_loss: 45.8208 - val_mae: 46.3203
# Epoch 90/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.7807 - mae: 54.2790
# Epoch 90: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0175 - mae: 54.5158 - val_loss: 45.1380 - val_mae: 45.6324
# Epoch 91/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.9437 - mae: 54.4417
# Epoch 91: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 16ms/step - loss: 53.9947 - mae: 54.4928 - val_loss: 45.2444 - val_mae: 45.7444
# Epoch 92/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.9929 - mae: 54.4913
# Epoch 92: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 21ms/step - loss: 54.1145 - mae: 54.6129 - val_loss: 45.3735 - val_mae: 45.8720
# Epoch 93/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.1051 - mae: 54.6035
# Epoch 93: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1272 - mae: 54.6256 - val_loss: 45.7731 - val_mae: 46.2719
# Epoch 94/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.0431 - mae: 54.5414
# Epoch 94: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.1365 - mae: 54.6347 - val_loss: 45.6000 - val_mae: 46.0995
# Epoch 95/100
# 89/93 [===========================>..] - ETA: 0s - loss: 53.9197 - mae: 54.4178
# Epoch 95: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0454 - mae: 54.5435 - val_loss: 45.7301 - val_mae: 46.2273
# Epoch 96/100
# 93/93 [==============================] - ETA: 0s - loss: 54.0971 - mae: 54.5954
# Epoch 96: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 14ms/step - loss: 54.0971 - mae: 54.5954 - val_loss: 45.3049 - val_mae: 45.8049
# Epoch 97/100
# 89/93 [===========================>..] - ETA: 0s - loss: 54.0833 - mae: 54.5816
# Epoch 97: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0615 - mae: 54.5598 - val_loss: 45.0630 - val_mae: 45.5611
# Epoch 98/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.0358 - mae: 54.5340
# Epoch 98: val_mae did not improve from 45.53495
# 93/93 [==============================] - 2s 21ms/step - loss: 54.0794 - mae: 54.5776 - val_loss: 45.5277 - val_mae: 46.0276
# Epoch 99/100
# 90/93 [============================>.] - ETA: 0s - loss: 53.8901 - mae: 54.3884
# Epoch 99: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.0533 - mae: 54.5516 - val_loss: 46.0410 - val_mae: 46.5372
# Epoch 100/100
# 92/93 [============================>.] - ETA: 0s - loss: 54.2482 - mae: 54.7462
# Epoch 100: val_mae did not improve from 45.53495
# 93/93 [==============================] - 1s 13ms/step - loss: 54.2625 - mae: 54.7605 - val_loss: 45.3584 - val_mae: 45.8575

# %% [markdown]
# ## 학습 완료 후 Load Weights (ModelCheckpoint)

# %% [markdown]
# 학습이 완료된 후에는 반드시 `load_weights`를 해주어야 합니다.
#
# 그렇지 않으면, 열심히 ModelCheckpoint를 만든 의미가 없습니다.

# %%
model.load_weights(checkpoint_path)

# %% [markdown]
# ## 학습 오차에 대한 시각화

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 9))
plt.plot(np.arange(1, epochs+1), history.history['loss'])
plt.plot(np.arange(1, epochs+1), history.history['val_loss'])
plt.title('Loss / Val Loss', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['loss', 'val_loss'], fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12, 9))
plt.plot(np.arange(1, epochs+1), history.history['mae'])
plt.plot(np.arange(1, epochs+1), history.history['val_mae'])
plt.title('MAE / Val MAE', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend(['mae', 'val_mae'], fontsize=15)
plt.show()
