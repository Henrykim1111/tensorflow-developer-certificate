# %% [markdown]
# <a href="https://colab.research.google.com/github/Henrykim1111/tensorflow-developer-certificate/blob/main/TF_Certificate_Category_5_(%EA%B0%95%EC%9D%98)%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Category 5
#
# Sequence (시계열) 데이터 다루기

# %% [markdown]
# ## 확인

# %% [markdown]
# 1. GPU 옵션 켜져 있는지 확인할 것!!! (수정 - 노트설정 - 하드웨어설정 (GPU))

# %% [markdown]
# ## 순서

# %% [markdown]
# 1. **import**: 필요한 모듈 import
# 2. **전처리**: 학습에 필요한 데이터 전처리를 수행합니다.
# 3. **모델링(model)**: 모델을 정의합니다.
# 4. **컴파일(compile)**: 모델을 생성합니다.
# 5. **학습 (fit)**: 모델을 학습시킵니다.

# %% [markdown]
# ## 문제

# %% [markdown]
# For this task you will need to train a neural network
# to predict sunspot activity using the Sunspots.csv
# provided.
#
# Your neural network is expected to have an MAE
# of at least 20, with top marks going to one with an MAE
# of around 15.
#
# At the bottom is provided some testing
# code should you want to check before uploading which measures
# the MAE for you.
#
# Strongly recommend you test your model with
# this to be able to see how it performs.
#
#
#
# -------------------------------
# **Sequence(시퀀스)**
#
# Sunspots.csv를 사용하여 **태양 흑점 활동(sunspot)**을 예측하는 인공신경망을 만듭니다.
#
# MAE 오차 기준으로 최소 20이하로 예측할 것을 권장하며, 탑 랭킹에 들려면 MAE 15 근처에 도달해야합니다.
#
# 아래 주어진 샘플코드는 당신의 모델을 테스트 하는 용도로 활용할 수 있습니다.

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ## 필요한 모듈 import

# %%
import csv
import tensorflow as tf
import numpy as np
import urllib

from tensorflow.keras.layers import Dense, LSTM, Lambda, Conv1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import Huber

# %%
url = 'https://storage.googleapis.com/download.tensorflow.org/data/Sunspots.csv'
urllib.request.urlretrieve(url, 'sunspots.csv')
# Out:
# ('sunspots.csv', <http.client.HTTPMessage at 0x78d17ac17f40>)

# %% [markdown]
# ## csv 파일로부터 데이터셋 만들기

# %% [markdown]
# csv.reader() 함수를 활용합니다.
#
# * 첫번째 파라미터에는 file을 , delimiter에는 구분자를 넣어 줍니다.

# %%
with open('sunspots.csv') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    i = 0
    for row in reader:
        print(row)
        i+=1
        if i > 10:
            break
# Out:
# ['0', '1749-01-31', '96.7']
# ['1', '1749-02-28', '104.3']
# ['2', '1749-03-31', '116.7']
# ['3', '1749-04-30', '92.8']
# ['4', '1749-05-31', '141.7']
# ['5', '1749-06-30', '139.2']
# ['6', '1749-07-31', '158.0']
# ['7', '1749-08-31', '110.5']
# ['8', '1749-09-30', '126.5']
# ['9', '1749-10-31', '125.8']
# ['10', '1749-11-30', '264.3']

# %% [markdown]
# 빈 list를 만들어 줍니다. (sunspots, time_step)

# %%
sunspots = []
time_step = []

# %% [markdown]
# `time_step`에는 **index** 값을, `sunspots`에는 sunspots의 정보를 넣어 줍니다.

# %%
with open('sunspots.csv') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    # 첫 줄은 header이므로 skip 합니다.
    next(reader)
    for row in reader:
        sunspots.append(float(row[2]))
        time_step.append(int(row[0]))

# %% [markdown]
# sunspots, time_step 확인

# %%
sunspots[:5]
# Out:
# [96.7, 104.3, 116.7, 92.8, 141.7]

# %%
time_step[:5]
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# sunspots와 time_step을 `numpy array`로 변환합니다.
#
# * 참고: 모델은 list 타입을 받아들이지 못합니다. 따라서, numpy array 로 변환해 줍니다.

# %%
series = np.array(sunspots)
time = np.array(time_step)

# %%
series.shape, time.shape
# Out:
# ((3235,), (3235,))

# %% [markdown]
# ## 태양의 흑점 활동 (sunspots) 시각화

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 8))
plt.plot(time, series)
plt.xlabel("Time")
plt.ylabel("Value")
plt.grid(True)

# %% [markdown]
# ## Train Set, Validation Set 생성

# %% [markdown]
# 3000 인덱스를 기준으로 Train / Validation Set를 분할 합니다.

# %%
split_time = 3000

# %%
time_train = time[:split_time]
time_valid = time[split_time:]

x_train = series[:split_time]
x_valid = series[split_time:]

# %% [markdown]
# ## Window Dataset Loader

# %% [markdown]
# 자세한 Dataset 활용법은 [블로그 링크](https://teddylee777.github.io/tensorflow/dataset-batch-window)를 참고해 보시고, 연습해보세요!

# %%
# 윈도우 사이즈
window_size=30
# 배치 사이즈
batch_size = 32
# 셔플 사이즈
shuffle_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)

# %% [markdown]
# `train_set`와 `validation_set`를 만듭니다.

# %%
train_set = windowed_dataset(x_train,
                             window_size=window_size,
                             batch_size=batch_size,
                             shuffle_buffer=shuffle_size)

validation_set = windowed_dataset(x_valid,
                                  window_size=window_size,
                                  batch_size=batch_size,
                                  shuffle_buffer=shuffle_size)

# %% [markdown]
# ## 모델 정의 (Sequential)

# %%
from IPython.display import Image

Image('https://i.stack.imgur.com/NmYZJ.png')

# %%
model = Sequential([
    tf.keras.layers.Conv1D(60, kernel_size=5,
                         padding="causal",
                         activation="relu",
                         input_shape=[None, 1]),
    tf.keras.layers.LSTM(60, return_sequences=True),
    tf.keras.layers.LSTM(60, return_sequences=True),
    tf.keras.layers.Dense(30, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 400)
])

# %% [markdown]
# 모델의 구조 요약을 확인합니다.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 60)          360
#
#  lstm (LSTM)                 (None, None, 60)          29040
#
#  lstm_1 (LSTM)               (None, None, 60)          29040
#
#  dense (Dense)               (None, None, 30)          1830
#
#  dense_1 (Dense)             (None, None, 10)          310
#
#  dense_2 (Dense)             (None, None, 1)           11
#
#  lambda (Lambda)             (None, None, 1)           0
#
# =================================================================
# Total params: 60591 (236.68 KB)
# Trainable params: 60591 (236.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 컴파일 (compile)

# %% [markdown]
# **Optimizer**는 SGD(Stochastic Gradient Descent) 를 사용합니다.
#
# * lr(learning_rate): 학습률입니다.
# * momentum: 모멘텀 (가중치) 입니다.

# %%
optimizer = SGD(learning_rate=1e-5, momentum=0.9)

# %% [markdown]
# **Huber Loss**: MSE와 MAE를 절충한 후버 손실(Huber loss)

# %% [markdown]
# \begin{split}L_{\delta}=\left\{\begin{matrix}
# \frac{1}{2}(y - \hat{y})^{2} & if \left | (y - \hat{y})  \right | < \delta\\
# \delta ((y - \hat{y}) - \frac1 2 \delta) & otherwise
# \end{matrix}\right.\end{split}

# %%
loss= Huber()

# %% [markdown]
# model.compile()시 우리가 튜닝한 **optimizer**와 **loss**를 활용합니다.

# %%
model.compile(loss=loss,
              optimizer=optimizer,
              metrics=["mae"])

# %% [markdown]
# ## ModelCheckpoint: 체크포인트 생성

# %% [markdown]
# `val_loss` 기준으로 epoch 마다 최적의 모델을 저장하기 위하여, ModelCheckpoint를 만듭니다.
# * `checkpoint_path`는 모델이 저장될 파일 명을 설정합니다.
# * `ModelCheckpoint`을 선언하고, 적절한 옵션 값을 지정합니다.

# %%
checkpoint_path = 'tmp_checkpoint.ckpt'
checkpoint = ModelCheckpoint(checkpoint_path,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_mae',
                             verbose=1)

# %% [markdown]
# ## 학습 (fit)

# %%
epochs=100

# %%
history = model.fit(train_set,
                    validation_data=(validation_set),
                    epochs=epochs,
                    callbacks=[checkpoint],
                   )
# Out:
# Epoch 1/100
#      93/Unknown - 9s 15ms/step - loss: 26.6300 - mae: 27.1244
# Epoch 1: val_mae improved from inf to 16.89113, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 10s 27ms/step - loss: 26.6300 - mae: 27.1244 - val_loss: 16.4000 - val_mae: 16.8911
# Epoch 2/100
# 89/93 [===========================>..] - ETA: 0s - loss: 21.0625 - mae: 21.5558
# Epoch 2: val_mae did not improve from 16.89113
# 93/93 [==============================] - 1s 12ms/step - loss: 20.9749 - mae: 21.4682 - val_loss: 17.0976 - val_mae: 17.5904
# Epoch 3/100
# 91/93 [============================>.] - ETA: 0s - loss: 19.2276 - mae: 19.7202
# Epoch 3: val_mae improved from 16.89113 to 15.14156, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 13ms/step - loss: 19.2320 - mae: 19.7247 - val_loss: 14.6497 - val_mae: 15.1416
# Epoch 4/100
# 91/93 [============================>.] - ETA: 0s - loss: 18.6512 - mae: 19.1438
# Epoch 4: val_mae did not improve from 15.14156
# 93/93 [==============================] - 1s 12ms/step - loss: 18.6355 - mae: 19.1280 - val_loss: 16.6884 - val_mae: 17.1805
# Epoch 5/100
# 90/93 [============================>.] - ETA: 0s - loss: 18.6061 - mae: 19.0982
# Epoch 5: val_mae improved from 15.14156 to 14.76075, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 2s 20ms/step - loss: 18.6108 - mae: 19.1029 - val_loss: 14.2728 - val_mae: 14.7607
# Epoch 6/100
# 88/93 [===========================>..] - ETA: 0s - loss: 18.3784 - mae: 18.8708
# Epoch 6: val_mae improved from 14.76075 to 14.61279, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 2s 14ms/step - loss: 18.3577 - mae: 18.8500 - val_loss: 14.1234 - val_mae: 14.6128
# Epoch 7/100
# 91/93 [============================>.] - ETA: 0s - loss: 17.8590 - mae: 18.3512
# Epoch 7: val_mae improved from 14.61279 to 14.43564, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 14ms/step - loss: 17.8656 - mae: 18.3577 - val_loss: 13.9466 - val_mae: 14.4356
# Epoch 8/100
# 92/93 [============================>.] - ETA: 0s - loss: 18.0355 - mae: 18.5275
# Epoch 8: val_mae did not improve from 14.43564
# 93/93 [==============================] - 1s 13ms/step - loss: 18.0266 - mae: 18.5187 - val_loss: 14.4969 - val_mae: 14.9897
# Epoch 9/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.7862 - mae: 18.2778
# Epoch 9: val_mae did not improve from 14.43564
# 93/93 [==============================] - 1s 14ms/step - loss: 17.7698 - mae: 18.2613 - val_loss: 14.3958 - val_mae: 14.8869
# Epoch 10/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.7845 - mae: 18.2762
# Epoch 10: val_mae improved from 14.43564 to 14.30064, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 13ms/step - loss: 17.7966 - mae: 18.2883 - val_loss: 13.8123 - val_mae: 14.3006
# Epoch 11/100
# 93/93 [==============================] - ETA: 0s - loss: 17.6070 - mae: 18.0983
# Epoch 11: val_mae improved from 14.30064 to 14.03485, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 13ms/step - loss: 17.6070 - mae: 18.0983 - val_loss: 13.5458 - val_mae: 14.0349
# Epoch 12/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.5740 - mae: 18.0652
# Epoch 12: val_mae did not improve from 14.03485
# 93/93 [==============================] - 2s 21ms/step - loss: 17.5738 - mae: 18.0650 - val_loss: 13.5546 - val_mae: 14.0439
# Epoch 13/100
# 89/93 [===========================>..] - ETA: 0s - loss: 17.6351 - mae: 18.1263
# Epoch 13: val_mae did not improve from 14.03485
# 93/93 [==============================] - 2s 17ms/step - loss: 17.5889 - mae: 18.0801 - val_loss: 14.1259 - val_mae: 14.6162
# Epoch 14/100
# 89/93 [===========================>..] - ETA: 0s - loss: 17.4924 - mae: 17.9836
# Epoch 14: val_mae did not improve from 14.03485
# 93/93 [==============================] - 1s 12ms/step - loss: 17.4353 - mae: 17.9266 - val_loss: 13.6996 - val_mae: 14.1883
# Epoch 15/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.3150 - mae: 17.8063
# Epoch 15: val_mae did not improve from 14.03485
# 93/93 [==============================] - 1s 15ms/step - loss: 17.3283 - mae: 17.8196 - val_loss: 13.9127 - val_mae: 14.4008
# Epoch 16/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.7330 - mae: 18.2244
# Epoch 16: val_mae did not improve from 14.03485
# 93/93 [==============================] - 2s 15ms/step - loss: 17.7127 - mae: 18.2041 - val_loss: 14.8835 - val_mae: 15.3747
# Epoch 17/100
# 91/93 [============================>.] - ETA: 0s - loss: 17.4992 - mae: 17.9904
# Epoch 17: val_mae did not improve from 14.03485
# 93/93 [==============================] - 1s 13ms/step - loss: 17.4562 - mae: 17.9474 - val_loss: 13.9815 - val_mae: 14.4708
# Epoch 18/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.5071 - mae: 17.9984
# Epoch 18: val_mae improved from 14.03485 to 13.92050, saving model to tmp_checkpoint.ckpt
# 93/93 [==============================] - 1s 13ms/step - loss: 17.5165 - mae: 18.0078 - val_loss: 13.4327 - val_mae: 13.9205
# Epoch 19/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.3021 - mae: 17.7931
# Epoch 19: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 25ms/step - loss: 17.2812 - mae: 17.7722 - val_loss: 13.5757 - val_mae: 14.0658
# Epoch 20/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.1909 - mae: 17.6818
# Epoch 20: val_mae did not improve from 13.92050
# 93/93 [==============================] - 3s 29ms/step - loss: 17.2018 - mae: 17.6927 - val_loss: 14.1662 - val_mae: 14.6543
# Epoch 21/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.2916 - mae: 17.7826
# Epoch 21: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 17.2716 - mae: 17.7625 - val_loss: 13.7263 - val_mae: 14.2126
# Epoch 22/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.1841 - mae: 17.6750
# Epoch 22: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 17.1781 - mae: 17.6691 - val_loss: 13.9262 - val_mae: 14.4172
# Epoch 23/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.1392 - mae: 17.6297
# Epoch 23: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 17.1809 - mae: 17.6715 - val_loss: 13.5689 - val_mae: 14.0585
# Epoch 24/100
# 91/93 [============================>.] - ETA: 0s - loss: 17.0767 - mae: 17.5673
# Epoch 24: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 17.0709 - mae: 17.5616 - val_loss: 13.6282 - val_mae: 14.1147
# Epoch 25/100
# 91/93 [============================>.] - ETA: 0s - loss: 17.3117 - mae: 17.8024
# Epoch 25: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 17.2821 - mae: 17.7728 - val_loss: 14.0373 - val_mae: 14.5251
# Epoch 26/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.1346 - mae: 17.6257
# Epoch 26: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 17.1741 - mae: 17.6652 - val_loss: 13.8962 - val_mae: 14.3850
# Epoch 27/100
# 93/93 [==============================] - ETA: 0s - loss: 17.3071 - mae: 17.7981
# Epoch 27: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 15ms/step - loss: 17.3071 - mae: 17.7981 - val_loss: 14.1312 - val_mae: 14.6190
# Epoch 28/100
# 88/93 [===========================>..] - ETA: 0s - loss: 17.1359 - mae: 17.6265
# Epoch 28: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 17.1513 - mae: 17.6419 - val_loss: 13.7533 - val_mae: 14.2414
# Epoch 29/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.1734 - mae: 17.6638
# Epoch 29: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 17.2294 - mae: 17.7199 - val_loss: 13.9059 - val_mae: 14.3981
# Epoch 30/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.1309 - mae: 17.6212
# Epoch 30: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 17.1484 - mae: 17.6387 - val_loss: 13.6616 - val_mae: 14.1499
# Epoch 31/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.1289 - mae: 17.6194
# Epoch 31: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 17.1172 - mae: 17.6078 - val_loss: 13.4758 - val_mae: 13.9639
# Epoch 32/100
# 91/93 [============================>.] - ETA: 0s - loss: 17.0310 - mae: 17.5215
# Epoch 32: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 17.0154 - mae: 17.5058 - val_loss: 13.6428 - val_mae: 14.1325
# Epoch 33/100
# 92/93 [============================>.] - ETA: 0s - loss: 17.0953 - mae: 17.5861
# Epoch 33: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 17.1191 - mae: 17.6100 - val_loss: 14.0234 - val_mae: 14.5114
# Epoch 34/100
# 90/93 [============================>.] - ETA: 0s - loss: 17.0555 - mae: 17.5459
# Epoch 34: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 17.0476 - mae: 17.5380 - val_loss: 13.6953 - val_mae: 14.1820
# Epoch 35/100
# 91/93 [============================>.] - ETA: 0s - loss: 17.1280 - mae: 17.6187
# Epoch 35: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 19ms/step - loss: 17.1590 - mae: 17.6497 - val_loss: 14.0394 - val_mae: 14.5310
# Epoch 36/100
# 93/93 [==============================] - ETA: 0s - loss: 17.0878 - mae: 17.5782
# Epoch 36: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 19ms/step - loss: 17.0878 - mae: 17.5782 - val_loss: 15.1969 - val_mae: 15.6864
# Epoch 37/100
# 93/93 [==============================] - ETA: 0s - loss: 16.9313 - mae: 17.4219
# Epoch 37: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.9313 - mae: 17.4219 - val_loss: 13.9150 - val_mae: 14.4061
# Epoch 38/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.9140 - mae: 17.4047
# Epoch 38: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.9283 - mae: 17.4191 - val_loss: 13.7826 - val_mae: 14.2735
# Epoch 39/100
# 93/93 [==============================] - ETA: 0s - loss: 17.0168 - mae: 17.5075
# Epoch 39: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 17.0168 - mae: 17.5075 - val_loss: 13.7640 - val_mae: 14.2524
# Epoch 40/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.8859 - mae: 17.3760
# Epoch 40: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.8893 - mae: 17.3794 - val_loss: 13.4906 - val_mae: 13.9798
# Epoch 41/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.7659 - mae: 17.2563
# Epoch 41: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.8065 - mae: 17.2969 - val_loss: 13.6137 - val_mae: 14.1033
# Epoch 42/100
# 93/93 [==============================] - ETA: 0s - loss: 16.9974 - mae: 17.4880
# Epoch 42: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.9974 - mae: 17.4880 - val_loss: 13.6024 - val_mae: 14.0903
# Epoch 43/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.7021 - mae: 17.1924
# Epoch 43: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.7377 - mae: 17.2280 - val_loss: 14.3235 - val_mae: 14.8124
# Epoch 44/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.8706 - mae: 17.3614
# Epoch 44: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.8699 - mae: 17.3606 - val_loss: 14.0651 - val_mae: 14.5549
# Epoch 45/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.8153 - mae: 17.3052
# Epoch 45: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 15ms/step - loss: 16.8746 - mae: 17.3647 - val_loss: 14.2205 - val_mae: 14.7112
# Epoch 46/100
# 93/93 [==============================] - ETA: 0s - loss: 16.9145 - mae: 17.4052
# Epoch 46: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.9145 - mae: 17.4052 - val_loss: 13.6191 - val_mae: 14.1057
# Epoch 47/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.9345 - mae: 17.4250
# Epoch 47: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.9063 - mae: 17.3968 - val_loss: 13.5279 - val_mae: 14.0147
# Epoch 48/100
# 93/93 [==============================] - ETA: 0s - loss: 16.7970 - mae: 17.2875
# Epoch 48: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.7970 - mae: 17.2875 - val_loss: 14.0509 - val_mae: 14.5413
# Epoch 49/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.8954 - mae: 17.3862
# Epoch 49: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.9378 - mae: 17.4285 - val_loss: 13.4906 - val_mae: 13.9792
# Epoch 50/100
# 88/93 [===========================>..] - ETA: 0s - loss: 16.7116 - mae: 17.2019
# Epoch 50: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.7520 - mae: 17.2423 - val_loss: 13.7733 - val_mae: 14.2619
# Epoch 51/100
# 93/93 [==============================] - ETA: 0s - loss: 16.7733 - mae: 17.2633
# Epoch 51: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.7733 - mae: 17.2633 - val_loss: 13.8097 - val_mae: 14.3004
# Epoch 52/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.6679 - mae: 17.1585
# Epoch 52: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.6887 - mae: 17.1792 - val_loss: 13.9180 - val_mae: 14.4081
# Epoch 53/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.7218 - mae: 17.2116
# Epoch 53: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 18ms/step - loss: 16.7142 - mae: 17.2040 - val_loss: 13.5305 - val_mae: 14.0189
# Epoch 54/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.6774 - mae: 17.1676
# Epoch 54: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.6920 - mae: 17.1822 - val_loss: 13.6977 - val_mae: 14.1849
# Epoch 55/100
# 93/93 [==============================] - ETA: 0s - loss: 16.6168 - mae: 17.1070
# Epoch 55: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.6168 - mae: 17.1070 - val_loss: 13.7987 - val_mae: 14.2884
# Epoch 56/100
# 93/93 [==============================] - ETA: 0s - loss: 16.6617 - mae: 17.1515
# Epoch 56: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.6617 - mae: 17.1515 - val_loss: 13.6455 - val_mae: 14.1345
# Epoch 57/100
# 93/93 [==============================] - ETA: 0s - loss: 16.5440 - mae: 17.0342
# Epoch 57: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.5440 - mae: 17.0342 - val_loss: 13.8019 - val_mae: 14.2894
# Epoch 58/100
# 93/93 [==============================] - ETA: 0s - loss: 16.6643 - mae: 17.1541
# Epoch 58: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.6643 - mae: 17.1541 - val_loss: 13.6542 - val_mae: 14.1406
# Epoch 59/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.5332 - mae: 17.0231
# Epoch 59: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 17ms/step - loss: 16.5369 - mae: 17.0267 - val_loss: 13.8145 - val_mae: 14.3008
# Epoch 60/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.5855 - mae: 17.0758
# Epoch 60: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 14ms/step - loss: 16.6065 - mae: 17.0968 - val_loss: 13.9133 - val_mae: 14.4027
# Epoch 61/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.5863 - mae: 17.0760
# Epoch 61: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.6159 - mae: 17.1056 - val_loss: 13.6757 - val_mae: 14.1637
# Epoch 62/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.4340 - mae: 16.9237
# Epoch 62: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.4618 - mae: 16.9516 - val_loss: 14.0828 - val_mae: 14.5741
# Epoch 63/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.5182 - mae: 17.0083
# Epoch 63: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.5115 - mae: 17.0016 - val_loss: 14.0802 - val_mae: 14.5699
# Epoch 64/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.4803 - mae: 16.9701
# Epoch 64: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.4609 - mae: 16.9507 - val_loss: 13.7491 - val_mae: 14.2407
# Epoch 65/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.4715 - mae: 16.9613
# Epoch 65: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.4687 - mae: 16.9585 - val_loss: 13.7499 - val_mae: 14.2377
# Epoch 66/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.4785 - mae: 16.9680
# Epoch 66: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.4704 - mae: 16.9600 - val_loss: 13.5584 - val_mae: 14.0474
# Epoch 67/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.4963 - mae: 16.9861
# Epoch 67: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 18ms/step - loss: 16.4956 - mae: 16.9855 - val_loss: 14.1850 - val_mae: 14.6748
# Epoch 68/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.6592 - mae: 17.1498
# Epoch 68: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 19ms/step - loss: 16.6787 - mae: 17.1693 - val_loss: 14.8140 - val_mae: 15.3055
# Epoch 69/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.5013 - mae: 16.9917
# Epoch 69: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.5213 - mae: 17.0117 - val_loss: 13.8228 - val_mae: 14.3092
# Epoch 70/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.3872 - mae: 16.8769
# Epoch 70: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.4224 - mae: 16.9121 - val_loss: 13.7509 - val_mae: 14.2391
# Epoch 71/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.5602 - mae: 17.0500
# Epoch 71: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.5917 - mae: 17.0816 - val_loss: 14.2032 - val_mae: 14.6943
# Epoch 72/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.3981 - mae: 16.8875
# Epoch 72: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.4171 - mae: 16.9065 - val_loss: 13.8312 - val_mae: 14.3188
# Epoch 73/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.4066 - mae: 16.8963
# Epoch 73: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.4040 - mae: 16.8938 - val_loss: 13.7123 - val_mae: 14.2014
# Epoch 74/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.3377 - mae: 16.8274
# Epoch 74: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.3412 - mae: 16.8309 - val_loss: 13.7811 - val_mae: 14.2709
# Epoch 75/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.3463 - mae: 16.8357
# Epoch 75: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 19ms/step - loss: 16.3158 - mae: 16.8052 - val_loss: 14.1865 - val_mae: 14.6793
# Epoch 76/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.3278 - mae: 16.8179
# Epoch 76: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 19ms/step - loss: 16.3128 - mae: 16.8028 - val_loss: 13.6776 - val_mae: 14.1671
# Epoch 77/100
# 93/93 [==============================] - ETA: 0s - loss: 16.4090 - mae: 16.8987
# Epoch 77: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.4090 - mae: 16.8987 - val_loss: 13.7731 - val_mae: 14.2616
# Epoch 78/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.3409 - mae: 16.8306
# Epoch 78: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.3294 - mae: 16.8192 - val_loss: 13.7127 - val_mae: 14.2013
# Epoch 79/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.3476 - mae: 16.8373
# Epoch 79: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.3901 - mae: 16.8799 - val_loss: 14.8398 - val_mae: 15.3295
# Epoch 80/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.5046 - mae: 16.9945
# Epoch 80: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.4899 - mae: 16.9798 - val_loss: 13.7114 - val_mae: 14.1995
# Epoch 81/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.3519 - mae: 16.8413
# Epoch 81: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 17ms/step - loss: 16.3756 - mae: 16.8651 - val_loss: 13.6031 - val_mae: 14.0923
# Epoch 82/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.2913 - mae: 16.7809
# Epoch 82: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 20ms/step - loss: 16.2798 - mae: 16.7694 - val_loss: 13.9864 - val_mae: 14.4756
# Epoch 83/100
# 93/93 [==============================] - ETA: 0s - loss: 16.2294 - mae: 16.7192
# Epoch 83: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 18ms/step - loss: 16.2294 - mae: 16.7192 - val_loss: 13.8895 - val_mae: 14.3774
# Epoch 84/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.2027 - mae: 16.6919
# Epoch 84: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.1927 - mae: 16.6819 - val_loss: 13.6788 - val_mae: 14.1663
# Epoch 85/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.2096 - mae: 16.6989
# Epoch 85: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.2284 - mae: 16.7177 - val_loss: 13.7633 - val_mae: 14.2508
# Epoch 86/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.3335 - mae: 16.8231
# Epoch 86: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.3038 - mae: 16.7934 - val_loss: 13.7141 - val_mae: 14.2029
# Epoch 87/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.2040 - mae: 16.6937
# Epoch 87: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.1991 - mae: 16.6888 - val_loss: 13.9701 - val_mae: 14.4596
# Epoch 88/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.1775 - mae: 16.6670
# Epoch 88: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.1861 - mae: 16.6757 - val_loss: 13.8433 - val_mae: 14.3339
# Epoch 89/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.2439 - mae: 16.7336
# Epoch 89: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.2500 - mae: 16.7398 - val_loss: 14.8862 - val_mae: 15.3761
# Epoch 90/100
# 93/93 [==============================] - ETA: 0s - loss: 16.1189 - mae: 16.6082
# Epoch 90: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 16ms/step - loss: 16.1189 - mae: 16.6082 - val_loss: 14.3950 - val_mae: 14.8859
# Epoch 91/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.5833 - mae: 17.0733
# Epoch 91: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 14ms/step - loss: 16.5599 - mae: 17.0499 - val_loss: 14.1782 - val_mae: 14.6664
# Epoch 92/100
# 88/93 [===========================>..] - ETA: 0s - loss: 16.3126 - mae: 16.8022
# Epoch 92: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.3268 - mae: 16.8166 - val_loss: 14.1503 - val_mae: 14.6416
# Epoch 93/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.1437 - mae: 16.6333
# Epoch 93: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.1443 - mae: 16.6338 - val_loss: 14.3774 - val_mae: 14.8666
# Epoch 94/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.0972 - mae: 16.5863
# Epoch 94: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.1047 - mae: 16.5938 - val_loss: 14.1401 - val_mae: 14.6288
# Epoch 95/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.1389 - mae: 16.6283
# Epoch 95: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.1569 - mae: 16.6463 - val_loss: 13.9237 - val_mae: 14.4121
# Epoch 96/100
# 92/93 [============================>.] - ETA: 0s - loss: 16.1437 - mae: 16.6339
# Epoch 96: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.1508 - mae: 16.6409 - val_loss: 14.0023 - val_mae: 14.4913
# Epoch 97/100
# 90/93 [============================>.] - ETA: 0s - loss: 16.0959 - mae: 16.5852
# Epoch 97: val_mae did not improve from 13.92050
# 93/93 [==============================] - 2s 17ms/step - loss: 16.0818 - mae: 16.5711 - val_loss: 13.7652 - val_mae: 14.2527
# Epoch 98/100
# 89/93 [===========================>..] - ETA: 0s - loss: 16.3270 - mae: 16.8167
# Epoch 98: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 14ms/step - loss: 16.3106 - mae: 16.8003 - val_loss: 14.1222 - val_mae: 14.6105
# Epoch 99/100
# 91/93 [============================>.] - ETA: 0s - loss: 16.2407 - mae: 16.7302
# Epoch 99: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 12ms/step - loss: 16.2462 - mae: 16.7358 - val_loss: 13.9393 - val_mae: 14.4288
# Epoch 100/100
# 88/93 [===========================>..] - ETA: 0s - loss: 16.1071 - mae: 16.5960
# Epoch 100: val_mae did not improve from 13.92050
# 93/93 [==============================] - 1s 13ms/step - loss: 16.1117 - mae: 16.6008 - val_loss: 14.0911 - val_mae: 14.5804

# %% [markdown]
# ## 학습 완료 후 Load Weights (ModelCheckpoint)

# %% [markdown]
# 학습이 완료된 후에는 반드시 `load_weights`를 해주어야 합니다.
#
# 그렇지 않으면, 열심히 ModelCheckpoint를 만든 의미가 없습니다.

# %%
model.load_weights(checkpoint_path)

# %% [markdown]
# ## 학습 오차에 대한 시각화

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 9))
plt.plot(np.arange(1, epochs+1), history.history['loss'])
plt.plot(np.arange(1, epochs+1), history.history['val_loss'])
plt.title('Loss / Val Loss', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['loss', 'val_loss'], fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12, 9))
plt.plot(np.arange(1, epochs+1), history.history['mae'])
plt.plot(np.arange(1, epochs+1), history.history['val_mae'])
plt.title('MAE / Val MAE', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend(['mae', 'val_mae'], fontsize=15)
plt.show()
