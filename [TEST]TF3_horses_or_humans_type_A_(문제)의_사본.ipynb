# %% [markdown]
# <a href="https://colab.research.google.com/github/Henrykim1111/tensorflow-developer-certificate/blob/main/%5BTEST%5DTF3_horses_or_humans_type_A_(%EB%AC%B8%EC%A0%9C)%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
####################################################
## [중요]
## 2023년 6월 1일 기준
## Google Colab에 설치된 텐서플로우(TensorFlow) 버전은 2.12 버전입니다.
## 시험에 제출 가능한 버전은 2.9.0 버전이기 때문에 버전을 다운그레이드 진행해야 합니다.
## 반드시 아래 코드를 실행하여 버전 다운그레이드 후 모델링을 진행하세요.
## 시험 볼 때는 현재 이 코드는 지워주셔야 합니다.
## 관련하여 궁금하신 점은 슬랙 커뮤니티에 질문 남겨 주세요.
####################################################
import urllib.request

url = 'https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/tfcert.py'
urllib.request.urlretrieve(url, 'tfcert.py')
# %run tfcert.py

import tensorflow as tf
import tensorflow_datasets as tfds

print(f'설치 완료 후 TensorFlow 버전: {tf.__version__}')
print(f'설치 완료 후 TensorFlow Datasets 버전: {tfds.__version__}')

## 시험을 위한 버전 확인 ###########
## TensorFlow:          2.9.0 #
## TensorFlow Datasets: 4.6.0 #
###############################

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# This task requires you to create a classifier for horses or humans using
# the provided dataset.
#
# Please make sure your final layer has 2 neurons, activated by softmax
# as shown. Do not change the provided output layer, or tests may fail.
#
# IMPORTANT: Please note that the test uses images that are 300x300 with
# 3 bytes color depth so be sure to design your input layer to accept
# these, or the tests will fail.
#

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 3 - Horses Or Humans type A
# val_loss: 0.028
# val_acc: 0.98
# =================================================== #
# =================================================== #


import urllib.request
import zipfile
import numpy as np
from IPython.display import Image

import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.applications import VGG16


dataset_name = 'horses_or_humans'
train_dataset = tfds.load(name=dataset_name, split='train[:80%]')
valid_dataset = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    x = data['image'] / 255
    y = data['label']
    return x, y

def solution_model():
    batch_size = 32
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)


    model = Sequential([
        tf.keras.layers.Conv2D(32,(3,3), activation='relu', input_shape=(300, 300, 3)),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(64,(3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128,(3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.25),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "tmp_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                                save_weights_only=True,
                                save_best_only=True,
                                monitor='val_loss',
                                verbose=1)

    model.fit(train_data,
              validation_data=(valid_data),
              epochs=25,
              callbacks=[checkpoint],
              )

    model.load_weights(checkpoint_path)

    return model



# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("TF3-horses-or-humans-type-A.h5")
# Out:
# Epoch 1/25
# 26/26 [==============================] - ETA: 0s - loss: 0.7334 - acc: 0.7628
# Epoch 1: val_loss improved from inf to 0.29295, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 5s 153ms/step - loss: 0.7334 - acc: 0.7628 - val_loss: 0.2929 - val_acc: 0.8878
# Epoch 2/25
# 26/26 [==============================] - ETA: 0s - loss: 0.1154 - acc: 0.9574
# Epoch 2: val_loss improved from 0.29295 to 0.11063, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 83ms/step - loss: 0.1154 - acc: 0.9574 - val_loss: 0.1106 - val_acc: 0.9463
# Epoch 3/25
# 26/26 [==============================] - ETA: 0s - loss: 0.0446 - acc: 0.9818
# Epoch 3: val_loss improved from 0.11063 to 0.03565, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0446 - acc: 0.9818 - val_loss: 0.0357 - val_acc: 0.9902
# Epoch 4/25
# 26/26 [==============================] - ETA: 0s - loss: 0.0229 - acc: 0.9915
# Epoch 4: val_loss improved from 0.03565 to 0.01263, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 95ms/step - loss: 0.0229 - acc: 0.9915 - val_loss: 0.0126 - val_acc: 0.9951
# Epoch 5/25
# 26/26 [==============================] - ETA: 0s - loss: 0.0275 - acc: 0.9891
# Epoch 5: val_loss did not improve from 0.01263
# 26/26 [==============================] - 2s 88ms/step - loss: 0.0275 - acc: 0.9891 - val_loss: 0.0248 - val_acc: 0.9854
# Epoch 6/25
# 26/26 [==============================] - ETA: 0s - loss: 0.0269 - acc: 0.9878
# Epoch 6: val_loss did not improve from 0.01263
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0269 - acc: 0.9878 - val_loss: 0.0195 - val_acc: 0.9951
# Epoch 7/25
# 26/26 [==============================] - ETA: 0s - loss: 0.0236 - acc: 0.9939
# Epoch 7: val_loss improved from 0.01263 to 0.00349, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0236 - acc: 0.9939 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 8/25
# 26/26 [==============================] - ETA: 0s - loss: 0.0032 - acc: 1.0000
# Epoch 8: val_loss improved from 0.00349 to 0.00237, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0024 - val_acc: 1.0000
# Epoch 9/25
# 26/26 [==============================] - ETA: 0s - loss: 0.0017 - acc: 1.0000
# Epoch 9: val_loss did not improve from 0.00237
# 26/26 [==============================] - 2s 88ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0164 - val_acc: 0.9902
# Epoch 10/25
# 26/26 [==============================] - ETA: 0s - loss: 0.0014 - acc: 1.0000
# Epoch 10: val_loss did not improve from 0.00237
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0074 - val_acc: 0.9951
# Epoch 11/25
# 26/26 [==============================] - ETA: 0s - loss: 3.0114e-04 - acc: 1.0000
# Epoch 11: val_loss did not improve from 0.00237
# 26/26 [==============================] - 2s 81ms/step - loss: 3.0114e-04 - acc: 1.0000 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 12/25
# 26/26 [==============================] - ETA: 0s - loss: 8.5612e-05 - acc: 1.0000
# Epoch 12: val_loss improved from 0.00237 to 0.00226, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 83ms/step - loss: 8.5612e-05 - acc: 1.0000 - val_loss: 0.0023 - val_acc: 1.0000
# Epoch 13/25
# 26/26 [==============================] - ETA: 0s - loss: 6.5446e-05 - acc: 1.0000
# Epoch 13: val_loss did not improve from 0.00226
# 26/26 [==============================] - 2s 81ms/step - loss: 6.5446e-05 - acc: 1.0000 - val_loss: 0.0023 - val_acc: 1.0000
# Epoch 14/25
# 26/26 [==============================] - ETA: 0s - loss: 5.2413e-05 - acc: 1.0000
# Epoch 14: val_loss improved from 0.00226 to 0.00224, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 91ms/step - loss: 5.2413e-05 - acc: 1.0000 - val_loss: 0.0022 - val_acc: 1.0000
# Epoch 15/25
# 26/26 [==============================] - ETA: 0s - loss: 5.5227e-05 - acc: 1.0000
# Epoch 15: val_loss improved from 0.00224 to 0.00195, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 88ms/step - loss: 5.5227e-05 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 1.0000
# Epoch 16/25
# 26/26 [==============================] - ETA: 0s - loss: 4.7705e-05 - acc: 1.0000
# Epoch 16: val_loss improved from 0.00195 to 0.00192, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 82ms/step - loss: 4.7705e-05 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 1.0000
# Epoch 17/25
# 26/26 [==============================] - ETA: 0s - loss: 4.2276e-05 - acc: 1.0000
# Epoch 17: val_loss improved from 0.00192 to 0.00186, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 82ms/step - loss: 4.2276e-05 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 1.0000
# Epoch 18/25
# 26/26 [==============================] - ETA: 0s - loss: 4.3083e-05 - acc: 1.0000
# Epoch 18: val_loss improved from 0.00186 to 0.00169, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 88ms/step - loss: 4.3083e-05 - acc: 1.0000 - val_loss: 0.0017 - val_acc: 1.0000
# Epoch 19/25
# 26/26 [==============================] - ETA: 0s - loss: 3.5902e-05 - acc: 1.0000
# Epoch 19: val_loss did not improve from 0.00169
# 26/26 [==============================] - 2s 87ms/step - loss: 3.5902e-05 - acc: 1.0000 - val_loss: 0.0018 - val_acc: 1.0000
# Epoch 20/25
# 26/26 [==============================] - ETA: 0s - loss: 3.4241e-05 - acc: 1.0000
# Epoch 20: val_loss did not improve from 0.00169
# 26/26 [==============================] - 2s 89ms/step - loss: 3.4241e-05 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 1.0000
# Epoch 21/25
# 26/26 [==============================] - ETA: 0s - loss: 2.6997e-05 - acc: 1.0000
# Epoch 21: val_loss did not improve from 0.00169
# 26/26 [==============================] - 2s 80ms/step - loss: 2.6997e-05 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 1.0000
# Epoch 22/25
# 26/26 [==============================] - ETA: 0s - loss: 2.9531e-05 - acc: 1.0000
# Epoch 22: val_loss did not improve from 0.00169
# 26/26 [==============================] - 2s 80ms/step - loss: 2.9531e-05 - acc: 1.0000 - val_loss: 0.0017 - val_acc: 1.0000
# Epoch 23/25
# 26/26 [==============================] - ETA: 0s - loss: 2.5160e-05 - acc: 1.0000
# Epoch 23: val_loss improved from 0.00169 to 0.00163, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 82ms/step - loss: 2.5160e-05 - acc: 1.0000 - val_loss: 0.0016 - val_acc: 1.0000
# Epoch 24/25
# 26/26 [==============================] - ETA: 0s - loss: 2.7253e-05 - acc: 1.0000
# Epoch 24: val_loss did not improve from 0.00163
# 26/26 [==============================] - 2s 80ms/step - loss: 2.7253e-05 - acc: 1.0000 - val_loss: 0.0016 - val_acc: 1.0000
# Epoch 25/25
# 26/26 [==============================] - ETA: 0s - loss: 2.8085e-05 - acc: 1.0000
# Epoch 25: val_loss improved from 0.00163 to 0.00162, saving model to tmp_checkpoint.ckpt
# 26/26 [==============================] - 2s 95ms/step - loss: 2.8085e-05 - acc: 1.0000 - val_loss: 0.0016 - val_acc: 1.0000
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
